# %% [markdown]
# # Task 2.2.10: Deep Learning Object Detection Assignment Part 2
#
# Welcome to the second part of the final assignment for this teaching unit. Now that you have trained your model on a new dataset, you must evaluate the model.

# %% [markdown]
# ### Assignment Task 4 - Model Testing
#
# Test the model on unknown images, the test part of your dataset.

# %%
# Test your trained model on images not seen during the training.

# %% [markdown]
# ### Assignment Task 5 - Model Evaluation
#
# Evaluate the model by calculating the Precision, Recall, and mAP values based on the results of inference on the testing dataset.

# %%
# Write function to calculate IoU.

# Calculate precision and recall values on the predictions made by your trained model on the test images.

# Calculate mAP value on the predictions made by your trained model on the test images.
