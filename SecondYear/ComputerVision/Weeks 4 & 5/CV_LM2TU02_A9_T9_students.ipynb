# %% [markdown]
# # Task 2.2.9: Deep Learning Object Detection Assignment Part 1
#
# Welcome to the first part of the final assignment for this teaching unit. In this assignment you will have to prepare a new dataset and train a YOLOv5 deep learning object detection model on this new dataset. You must correctly prepare the dataset, define the hyperparameters for training, train the model and finally evaluate the success of the model using the metrics covered in this unit.

# %% [markdown]
# ### Assignment Task 1 - Dataset Preparation
#
# Find or create a new image dataset with labels to train the model on. Prepare the dataset and ensure that you have a training set, a validation set, and a testing set, each with labels of the ground truth bounding boxes.

# %%
# Create or find and then prepare a new dataset, that was not used during the course.

# %% [markdown]
# ### Assignment Task 2 - Model Training Preparation
#
# Ensure that you have your environment set up correctly. Create the necessary `.yaml` configuration and dataset files, and specify all necessary information regarding your dataset. Double check that this has been done correctly by printing out the contents of each file.

# %%
# Prepare the necessary configuration files required for training the YOLOv5s model on your new dataset.

# %% [markdown]
# ### Assignment Task 3 - Model Training
#
# Train the YOLOv5s model on your new dataset.

# %%
# Train the YOLOv5s model on your new dataset.
