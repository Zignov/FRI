# %% [markdown]
# # Task 2.2.6: Training the YOLOv5 Model
# ## Training the YOLOv5 model using the custom dataset and evaluating its initial performance.

# %% [markdown]
# #### Selecting the configuration

# %%
# We can view the contents of the YAML file directly in this notebook, by using Python to open and display the file
# Load and display the content of the YAML configuration file
with open("C:/Users/vasja/Desktop/AIM4VET/LM2TU2/yolo/yolov5/models/custom_yolov5s.yaml", 'r') as file:
    yaml_content = file.read()
    print(yaml_content)

# %%
# Load and display the content of the YAML dataset configuration file
with open("C:/Users/vasja/Desktop/AIM4VET/LM2TU2/yolo/yolov5/data/my_dataset.yaml", 'r') as file:
    yaml_content = file.read()
    print(yaml_content)

# %% [markdown]
# #### Initiating the Training Process

# %%
# We will run the training file from our terminal
# Open your terminal and navigate to the folder where YOLOv5 is located on your PC

# Run the following command in bash:
'''
python train.py --img 384 --batch 4 --epochs 50 --data ./data/my_dataset.yaml --cfg ./models/custom_yolov5s.yaml --weights yolov5s.pt --name my_first_model
'''

# %%
# Once the training has begun, you can use tensorboard to visualize information about the model and its training in real time.
# Run the following two python code snippets to first load and then launch a tensorboard session.

# %load_ext tensorboard

# %%
# %tensorboard --logdir C:/Users/vasja/Desktop/AIM4VET/LM2TU2/yolo/yolov5/runs/train
